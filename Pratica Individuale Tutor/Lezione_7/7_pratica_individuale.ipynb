# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# **POWER BI**
#
# A partire dai seguenti dati in allegato *Products.xlsx* e dai dati che potete trovare qui https://services.odata.org/V3/Northwind/Northwind.svc/ (tipo origine dato Feed OData) , creare una dashboard il più simile possibile a questa che vedi in Power BI

# %% [markdown]
# LineTotal è dato dal Prezzo unitario moltiplicato per la quantità di ogni ordine

# %%
import os
from IPython import display
display.Image('sales-data-filtered-for-canada (2).png')
